# %%
from dotenv import load_dotenv
from openai import OpenAI
import pandas as pd
import time
import pickle
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

load_dotenv()
client = OpenAI()

# Test queries about Gemini (without RAG context)
TEST_QUERIES = [
    "What are the key capabilities of Gemini models?",
    "How does Gemini compare to other multimodal models?", 
    "What are the different versions of Gemini?",
    "What training data was used for Gemini?",
    "What are the safety measures in Gemini models?"
]

temperatures = [0.0, 0.2, 0.5, 0.8, 1.2]

# %%
# LLM Judge for Answer Evaluation
def llm_judge(query, answer, judge_model="gpt-4o-mini"):
    judge_prompt = f"""
You are an expert evaluator. Assess this answer to the given question.

QUESTION: {query}

ANSWER: {answer}

Evaluate on these 3 criteria using this scale:
- Poor: Incorrect, incomplete, or irrelevant
- Below Average: Partially correct but missing key information  
- Average: Correct but basic, meets minimum requirements
- Good: Comprehensive, accurate, and well-structured
- Excellent: Outstanding accuracy, completeness, and clarity

CRITERIA:
1. Accuracy: Is the answer factually correct?
2. Completeness: Does it address all parts of the question?
3. Clarity: Is it well-structured and easy to understand?

Respond in this exact format:
Accuracy: [Rating]
Completeness: [Rating] 
Clarity: [Rating]
Overall: [Rating]
Reasoning: [Brief explanation]
"""
    
    try:
        response = client.chat.completions.create(
            model=judge_model,
            messages=[{"role": "user", "content": judge_prompt}],
            temperature=0.1,
            max_tokens=300
        )
        
        evaluation = response.choices[0].message.content
        
        # Parse the evaluation
        lines = evaluation.strip().split('\n')
        result = {}
        
        for line in lines:
            if ':' in line:
                key, value = line.split(':', 1)
                result[key.strip().lower()] = value.strip()
        
        return {
            'accuracy': result.get('accuracy', 'N/A'),
            'completeness': result.get('completeness', 'N/A'),
            'clarity': result.get('clarity', 'N/A'),
            'overall': result.get('overall', 'N/A'),
            'reasoning': result.get('reasoning', 'N/A')
        }
        
    except Exception as e:
        return {
            'accuracy': 'Error',
            'completeness': 'Error', 
            'clarity': 'Error',
            'overall': 'Error',
            'reasoning': f'Evaluation failed: {str(e)}'
        }

print("LLM Judge function ready")
# Out:
# LLM Judge function ready

# %%
# Part 1: Non-RAG Temperature Experiment
def run_non_rag_experiment(query, temp):
    start = time.time()
    
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": query}],
        temperature=temp,
        max_tokens=200
    )
    
    latency = time.time() - start
    answer = response.choices[0].message.content
    
    # Get LLM judge evaluation
    evaluation = llm_judge(query, answer)
    
    return {
        "query": query,
        "temperature": temp,
        "answer": answer,
        "latency": round(latency, 2),
        "tokens": response.usage.total_tokens,
        "accuracy": evaluation['accuracy'],
        "completeness": evaluation['completeness'],
        "clarity": evaluation['clarity'],
        "overall_rating": evaluation['overall'],
        "reasoning": evaluation['reasoning']
    }

# Run Non-RAG experiments
print("Running Non-RAG temperature experiments...")
non_rag_results = []

for query in TEST_QUERIES:
    for temp in temperatures:
        print(f"Testing query: '{query[:50]}...' at temperature {temp}")
        result = run_non_rag_experiment(query, temp)
        non_rag_results.append(result)
        time.sleep(1)  # Rate limiting

non_rag_df = pd.DataFrame(non_rag_results)
print(f"\nCompleted {len(non_rag_results)} Non-RAG experiments")
# Out:
# Running Non-RAG temperature experiments...
# Testing query: 'What are the key capabilities of Gemini models?...' at temperature 0.0
# Testing query: 'What are the key capabilities of Gemini models?...' at temperature 0.2
# Testing query: 'What are the key capabilities of Gemini models?...' at temperature 0.5
# Testing query: 'What are the key capabilities of Gemini models?...' at temperature 0.8
# Testing query: 'What are the key capabilities of Gemini models?...' at temperature 1.2
# Testing query: 'How does Gemini compare to other multimodal models...' at temperature 0.0
# Testing query: 'How does Gemini compare to other multimodal models...' at temperature 0.2
# Testing query: 'How does Gemini compare to other multimodal models...' at temperature 0.5
# Testing query: 'How does Gemini compare to other multimodal models...' at temperature 0.8
# Testing query: 'How does Gemini compare to other multimodal models...' at temperature 1.2
# Testing query: 'What are the different versions of Gemini?...' at temperature 0.0
# Testing query: 'What are the different versions of Gemini?...' at temperature 0.2
# Testing query: 'What are the different versions of Gemini?...' at temperature 0.5
# Testing query: 'What are the different versions of Gemini?...' at temperature 0.8
# Testing query: 'What are the different versions of Gemini?...' at temperature 1.2
# Testing query: 'What training data was used for Gemini?...' at temperature 0.0
# Testing query: 'What training data was used for Gemini?...' at temperature 0.2
# Testing query: 'What training data was used for Gemini?...' at temperature 0.5
# Testing query: 'What training data was used for Gemini?...' at temperature 0.8
# Testing query: 'What training data was used for Gemini?...' at temperature 1.2
# Testing query: 'What are the safety measures in Gemini models?...' at temperature 0.0
# Testing query: 'What are the safety measures in Gemini models?...' at temperature 0.2
# Testing query: 'What are the safety measures in Gemini models?...' at temperature 0.5
# Testing query: 'What are the safety measures in Gemini models?...' at temperature 0.8
# Testing query: 'What are the safety measures in Gemini models?...' at temperature 1.2
#
# Completed 25 Non-RAG experiments

# %%
non_rag_df
# Out:
#                                                 query  temperature  \
# 0     What are the key capabilities of Gemini models?          0.0
# 1     What are the key capabilities of Gemini models?          0.2
# 2     What are the key capabilities of Gemini models?          0.5
# 3     What are the key capabilities of Gemini models?          0.8
# 4     What are the key capabilities of Gemini models?          1.2
# 5   How does Gemini compare to other multimodal mo...          0.0
# 6   How does Gemini compare to other multimodal mo...          0.2
# 7   How does Gemini compare to other multimodal mo...          0.5
# 8   How does Gemini compare to other multimodal mo...          0.8
# 9   How does Gemini compare to other multimodal mo...          1.2
# 10         What are the different versions of Gemini?          0.0
# 11         What are the different versions of Gemini?          0.2
# 12         What are the different versions of Gemini?          0.5
# 13         What are the different versions of Gemini?          0.8
# 14         What are the different versions of Gemini?          1.2
# 15            What training data was used for Gemini?          0.0
# 16            What training data was used for Gemini?          0.2
# 17            What training data was used for Gemini?          0.5
# 18            What training data was used for Gemini?          0.8
# 19            What training data was used for Gemini?          1.2
# 20     What are the safety measures in Gemini models?          0.0
# 21     What are the safety measures in Gemini models?          0.2
# 22     What are the safety measures in Gemini models?          0.5
# 23     What are the safety measures in Gemini models?          0.8
# 24     What are the safety measures in Gemini models?          1.2
#
#                                                answer  latency  tokens  \
# 0   As of my last update in October 2023, Gemini m...     4.42     216
# 1   As of my last update in October 2023, Gemini m...     5.00     216
# 2   As of my last update in October 2023, Gemini m...     5.10     216
# 3   As of my last update in October 2023, Gemini m...     4.98     216
# 4   As of October 2023, Gemini models, developed b...     4.84     216
# 5   As of my last update in October 2023, Gemini i...     4.81     217
# 6   As of my last update in October 2023, Gemini i...     4.67     217
# 7   As of my last update in October 2023, Gemini i...     7.31     217
# 8   As of my last knowledge update in October 2023...     4.91     217
# 9   As of my last knowledge update in October 2023...     4.72     217
# 10  As of my last knowledge update in October 2023...     5.20     215
# 11  As of my last update in October 2023, "Gemini"...     3.88     215
# 12  As of my last knowledge update in October 2023...     3.75     215
# 13  As of my last knowledge update in October 2023...     4.65     215
# 14  As of my last knowledge update in October 2023...     4.39     173
# 15  As of my last update in October 2023, specific...     2.24     116
# 16  As of my last update in October 2023, specific...     2.37     118
# 17  As of my last knowledge update in October 2023...     2.15     114
# 18  As of my last update in October 2023, specific...     1.83     107
# 19  As of my last update in October 2023, specific...     2.76     125
# 20  As of my last update in October 2023, Gemini m...     4.69     216
# 21  As of my last update in October 2023, Gemini m...     3.66     216
# 22  As of my last update in October 2023, the Gemi...     4.23     216
# 23  As of my last update in October 2023, safety m...     3.57     216
# 24  While I don't have specific details on Gemini ...     4.10     216
#
#          accuracy   completeness  clarity overall_rating  \
# 0            Good  Below Average     Good           Good
# 1            Good  Below Average     Good           Good
# 2            Good  Below Average     Good           Good
# 3            Good        Average     Good           Good
# 4            Good  Below Average     Good           Good
# 5            Good  Below Average     Good  Below Average
# 6            Good  Below Average     Good           Good
# 7            Good  Below Average     Good           Good
# 8            Good  Below Average     Good  Below Average
# 9            Good  Below Average     Good  Below Average
# 10           Good  Below Average     Good  Below Average
# 11           Good  Below Average     Good  Below Average
# 12           Good  Below Average     Good           Good
# 13           Good        Average     Good           Good
# 14           Good  Below Average     Good  Below Average
# 15           Good  Below Average     Good           Good
# 16           Good  Below Average     Good           Good
# 17           Good  Below Average     Good           Good
# 18           Good  Below Average     Good           Good
# 19           Good  Below Average     Good           Good
# 20           Good  Below Average     Good           Good
# 21           Good        Average     Good           Good
# 22           Good  Below Average     Good  Below Average
# 23           Good        Average     Good           Good
# 24  Below Average  Below Average  Average  Below Average
#
#                                             reasoning
# 0   The answer is factually correct regarding the ...
# 1   The answer accurately describes the capabiliti...
# 2   The answer provides accurate information about...
# 3   The answer is factually correct regarding the ...
# 4   The answer accurately describes the capabiliti...
# 5   The answer provides accurate information about...
# 6   The answer is factually correct regarding Gemi...
# 7   The answer is factually correct regarding Gemi...
# 8   The answer is factually correct regarding Gemi...
# 9   The answer is factually correct regarding Gemi...
# 10  The answer is factually correct regarding the ...
# 11  The answer is factually correct regarding the ...
# 12  The answer is factually correct regarding the ...
# 13  The answer provides accurate information about...
# 14  The answer provides accurate information regar...
# 15  The answer is factually correct regarding the ...
# 16  The answer is factually correct regarding the ...
# 17  The answer is factually correct regarding the ...
# 18  The answer is factually correct regarding the ...
# 19  The answer is factually correct regarding the ...
# 20  The answer provides accurate information regar...
# 21  The answer provides accurate information regar...
# 22  The answer is largely accurate regarding the s...
# 23  The answer is factually correct regarding the ...
# 24  The answer lacks specific details about the sa...

# %%
# Load RAG embeddings
with open('../data/rag_embeddings.pkl', 'rb') as f:
    rag_data = pickle.load(f)

chunks = rag_data['chunks']
embeddings = rag_data['embeddings']

print(f"Loaded {len(chunks)} chunks for RAG experiments")

# RAG retrieval function
def get_embedding(text, model="text-embedding-3-small"):
    text = text.replace("\n", " ")
    return client.embeddings.create(input=[text], model=model).data[0].embedding

def retrieve_chunks(query, chunks, embeddings, k=3):
    query_embedding = get_embedding(query)
    similarities = cosine_similarity([query_embedding], embeddings)[0]
    top_indices = np.argsort(similarities)[::-1][:k]
    
    retrieved_chunks = []
    for idx in top_indices:
        retrieved_chunks.append({
            'chunk': chunks[idx],
            'similarity': similarities[idx]
        })
    
    return retrieved_chunks
# Out:
# Loaded 82 chunks for RAG experiments

# %%
# Part 2: RAG Temperature Experiment
def run_rag_experiment(query, temp):
    start = time.time()
    
    # Retrieve relevant chunks
    retrieved = retrieve_chunks(query, chunks, embeddings, k=3)
    context = "\n\n".join([item['chunk']['text'] for item in retrieved])
    
    # Generate response with context
    prompt = f"""
Use the context below to answer the question. Be accurate and cite specific information from the context.

Context:
{context}

Question: {query}

Answer:"""
    
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=temp,
        max_tokens=200
    )
    
    latency = time.time() - start
    answer = response.choices[0].message.content
    
    # Get LLM judge evaluation (with context)
    judge_prompt = f"""
You are an expert evaluator. Assess this RAG answer based on the given context.

CONTEXT:
{context}

QUESTION: {query}

ANSWER: {answer}

Evaluate on these 3 criteria using this scale:
- Poor: Incorrect, incomplete, or irrelevant
- Below Average: Partially correct but missing key information  
- Average: Correct but basic, meets minimum requirements
- Good: Comprehensive, accurate, and well-structured
- Excellent: Outstanding accuracy, completeness, and clarity

CRITERIA:
1. Accuracy: Is the answer factually correct based on the context?
2. Completeness: Does it address all parts of the question?
3. Clarity: Is it well-structured and easy to understand?

Respond in this exact format:
Accuracy: [Rating]
Completeness: [Rating] 
Clarity: [Rating]
Overall: [Rating]
Reasoning: [Brief explanation]
"""
    
    try:
        judge_response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[{"role": "user", "content": judge_prompt}],
            temperature=0.1,
            max_tokens=300
        )
        
        evaluation = judge_response.choices[0].message.content
        lines = evaluation.strip().split('\n')
        result = {}
        
        for line in lines:
            if ':' in line:
                key, value = line.split(':', 1)
                result[key.strip().lower()] = value.strip()
        
        eval_result = {
            'accuracy': result.get('accuracy', 'N/A'),
            'completeness': result.get('completeness', 'N/A'),
            'clarity': result.get('clarity', 'N/A'),
            'overall': result.get('overall', 'N/A'),
            'reasoning': result.get('reasoning', 'N/A')
        }
        
    except Exception as e:
        eval_result = {
            'accuracy': 'Error',
            'completeness': 'Error', 
            'clarity': 'Error',
            'overall': 'Error',
            'reasoning': f'Evaluation failed: {str(e)}'
        }
    
    return {
        "query": query,
        "temperature": temp,
        "answer": answer,
        "context_length": len(context),
        "latency": round(latency, 2),
        "tokens": response.usage.total_tokens,
        "accuracy": eval_result['accuracy'],
        "completeness": eval_result['completeness'],
        "clarity": eval_result['clarity'],
        "overall_rating": eval_result['overall'],
        "reasoning": eval_result['reasoning']
    }

# Run RAG experiments
print("\nRunning RAG temperature experiments...")
rag_results = []

for query in TEST_QUERIES:
    for temp in temperatures:
        print(f"Testing RAG query: '{query[:50]}...' at temperature {temp}")
        result = run_rag_experiment(query, temp)
        rag_results.append(result)
        time.sleep(1)  # Rate limiting

rag_df = pd.DataFrame(rag_results)
print(f"\nCompleted {len(rag_results)} RAG experiments")
# Out:
# Running RAG temperature experiments...
# Testing RAG query: 'What are the key capabilities of Gemini models?...' at temperature 0.0
# Testing RAG query: 'What are the key capabilities of Gemini models?...' at temperature 0.2
# Testing RAG query: 'What are the key capabilities of Gemini models?...' at temperature 0.5
# Testing RAG query: 'What are the key capabilities of Gemini models?...' at temperature 0.8
# Testing RAG query: 'What are the key capabilities of Gemini models?...' at temperature 1.2
# Testing RAG query: 'How does Gemini compare to other multimodal models...' at temperature 0.0
# Testing RAG query: 'How does Gemini compare to other multimodal models...' at temperature 0.2
# Testing RAG query: 'How does Gemini compare to other multimodal models...' at temperature 0.5
# Testing RAG query: 'How does Gemini compare to other multimodal models...' at temperature 0.8
# Testing RAG query: 'How does Gemini compare to other multimodal models...' at temperature 1.2
# Testing RAG query: 'What are the different versions of Gemini?...' at temperature 0.0
# Testing RAG query: 'What are the different versions of Gemini?...' at temperature 0.2
# Testing RAG query: 'What are the different versions of Gemini?...' at temperature 0.5
# Testing RAG query: 'What are the different versions of Gemini?...' at temperature 0.8
# Testing RAG query: 'What are the different versions of Gemini?...' at temperature 1.2
# Testing RAG query: 'What training data was used for Gemini?...' at temperature 0.0
# Testing RAG query: 'What training data was used for Gemini?...' at temperature 0.2
# Testing RAG query: 'What training data was used for Gemini?...' at temperature 0.5
# Testing RAG query: 'What training data was used for Gemini?...' at temperature 0.8
# Testing RAG query: 'What training data was used for Gemini?...' at temperature 1.2
# Testing RAG query: 'What are the safety measures in Gemini models?...' at temperature 0.0
# Testing RAG query: 'What are the safety measures in Gemini models?...' at temperature 0.2
# Testing RAG query: 'What are the safety measures in Gemini models?...' at temperature 0.5
# Testing RAG query: 'What are the safety measures in Gemini models?...' at temperature 0.8
# Testing RAG query: 'What are the safety measures in Gemini models?...' at temperature 1.2
#
# Completed 25 RAG experiments

# %%
rag_df
# Out:
#                                                 query  temperature  \
# 0     What are the key capabilities of Gemini models?          0.0
# 1     What are the key capabilities of Gemini models?          0.2
# 2     What are the key capabilities of Gemini models?          0.5
# 3     What are the key capabilities of Gemini models?          0.8
# 4     What are the key capabilities of Gemini models?          1.2
# 5   How does Gemini compare to other multimodal mo...          0.0
# 6   How does Gemini compare to other multimodal mo...          0.2
# 7   How does Gemini compare to other multimodal mo...          0.5
# 8   How does Gemini compare to other multimodal mo...          0.8
# 9   How does Gemini compare to other multimodal mo...          1.2
# 10         What are the different versions of Gemini?          0.0
# 11         What are the different versions of Gemini?          0.2
# 12         What are the different versions of Gemini?          0.5
# 13         What are the different versions of Gemini?          0.8
# 14         What are the different versions of Gemini?          1.2
# 15            What training data was used for Gemini?          0.0
# 16            What training data was used for Gemini?          0.2
# 17            What training data was used for Gemini?          0.5
# 18            What training data was used for Gemini?          0.8
# 19            What training data was used for Gemini?          1.2
# 20     What are the safety measures in Gemini models?          0.0
# 21     What are the safety measures in Gemini models?          0.2
# 22     What are the safety measures in Gemini models?          0.5
# 23     What are the safety measures in Gemini models?          0.8
# 24     What are the safety measures in Gemini models?          1.2
#
#                                                answer  context_length  \
# 0   The key capabilities of Gemini models include:...           10375
# 1   The key capabilities of Gemini models include:...           10375
# 2   The key capabilities of Gemini models include:...           10375
# 3   The key capabilities of Gemini models include ...           10375
# 4   The key capabilities of Gemini models include:...           10375
# 5   Gemini models, particularly the Gemini Ultra v...           10168
# 6   Gemini models, particularly the Gemini Ultra v...           10168
# 7   Gemini models, particularly the Gemini Ultra v...           10168
# 8   Gemini models, particularly the Gemini Ultra, ...           10168
# 9   Gemini is positioned as a highly capable multi...           10168
# 10  The different versions of Gemini are known as ...           10389
# 11  The different versions of Gemini are known as ...           10389
# 12  The different versions of Gemini are known as ...           10389
# 13  The different versions of Gemini are known as ...           10389
# 14  The different versions of Gemini, as mentioned...           10389
# 15  Gemini models were trained on a dataset that i...           10227
# 16  Gemini models were trained on a dataset that i...           10227
# 17  Gemini models were trained on a dataset that i...           10227
# 18  The training data used for Gemini models is de...           10227
# 19  Gemini models were trained on a pre-training d...           10227
# 20  The safety measures in Gemini models include a...           10325
# 21  The safety measures in Gemini models include a...           10325
# 22  The Gemini models implement several safety mea...           10325
# 23  The Gemini models implement a variety of safet...           10325
# 24  The safety measures in Gemini models include s...           10325
#
#     latency  tokens   accuracy   completeness clarity overall_rating  \
# 0      4.28    2528       Good           Good    Good           Good
# 1      4.27    2528       Good        Average    Good           Good
# 2      4.54    2528       Good           Good    Good           Good
# 3      4.45    2528       Good           Good    Good           Good
# 4      3.78    2528  Excellent           Good    Good           Good
# 5      7.41    2305       Good           Good    Good           Good
# 6      4.08    2305  Excellent           Good    Good           Good
# 7      3.82    2305  Excellent           Good    Good           Good
# 8      4.27    2305  Excellent           Good    Good           Good
# 9      4.33    2305  Excellent           Good    Good           Good
# 10     1.68    2391       Good        Average    Good           Good
# 11     2.05    2391       Good        Average    Good        Average
# 12     1.60    2391       Good        Average    Good        Average
# 13     2.89    2391       Good        Average    Good        Average
# 14     1.65    2397       Good        Average    Good        Average
# 15     4.33    2480       Good           Good    Good           Good
# 16     7.24    2478  Excellent      Excellent    Good      Excellent
# 17     2.67    2445       Good           Good    Good           Good
# 18     3.46    2476       Good           Good    Good           Good
# 19     3.34    2474       Good           Good    Good           Good
# 20     4.12    2107       Good  Below Average    Good  Below Average
# 21     4.10    2107       Good        Average    Good           Good
# 22     3.80    2107       Good  Below Average    Good           Good
# 23     4.33    2107       Good  Below Average    Good           Good
# 24     3.92    2107       Good  Below Average    Good           Good
#
#                                             reasoning
# 0   The answer accurately reflects the key capabil...
# 1   The answer accurately captures the key capabil...
# 2   The answer accurately captures the key capabil...
# 3   The answer accurately reflects the key capabil...
# 4   The answer accurately reflects the key capabil...
# 5   The answer accurately reflects the advancement...
# 6   The answer accurately reflects the advancement...
# 7   The answer accurately reflects the information...
# 8   The answer accurately reflects the strengths o...
# 9   The answer accurately reflects the strengths o...
# 10  The answer accurately identifies the different...
# 11  The answer accurately identifies the different...
# 12  The answer accurately identifies the different...
# 13  The answer accurately identifies the different...
# 14  The answer accurately identifies the different...
# 15  The answer accurately describes the training d...
# 16  The answer accurately reflects the training da...
# 17  The answer accurately describes the training d...
# 18  The answer accurately describes the training d...
# 19  The answer accurately describes the training d...
# 20  The answer accurately describes several safety...
# 21  The answer accurately describes several key sa...
# 22  The answer accurately describes several safety...
# 23  The answer accurately describes several safety...
# 24  The answer accurately describes several safety...
